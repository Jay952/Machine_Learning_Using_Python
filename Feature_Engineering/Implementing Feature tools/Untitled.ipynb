# %%
import pandas as pd

# %%
# !python -m pip install featuretools
# Out:
# Collecting featuretools
#   Using cached https://files.pythonhosted.org/packages/dc/63/598d678b0fda9c2bacc42d4e0dc01350f0ede7a4266e79027c0c194a57c0/featuretools-0.14.0-py3-none-any.whl
# Requirement already satisfied: click>=7.0.0 in c:\users\admin\anaconda3\lib\site-packages (from featuretools) (7.0)
# Requirement already satisfied: pyyaml>=3.12 in c:\users\admin\appdata\roaming\python\python37\site-packages (from featuretools) (3.13)
# Requirement already satisfied: dask>=1.1.0 in c:\users\admin\anaconda3\lib\site-packages (from featuretools) (2.1.0)
# Requirement already satisfied: tqdm>=4.32.0 in c:\users\admin\anaconda3\lib\site-packages (from featuretools) (4.32.1)
# Requirement already satisfied: distributed>=1.24.2 in c:\users\admin\anaconda3\lib\site-packages (from featuretools) (2.1.0)
# Requirement already satisfied: psutil>=5.4.8 in c:\users\admin\anaconda3\lib\site-packages (from featuretools) (5.6.3)
# Requirement already satisfied: pandas>=0.24.1 in c:\users\admin\anaconda3\lib\site-packages (from featuretools) (0.24.2)
# Requirement already satisfied: scipy>=0.13.3 in c:\users\admin\anaconda3\lib\site-packages (from featuretools) (1.2.1)
# Requirement already satisfied: cloudpickle>=0.4.0 in c:\users\admin\anaconda3\lib\site-packages (from featuretools) (1.2.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\admin\anaconda3\lib\site-packages (from featuretools) (1.16.4)
# Requirement already satisfied: tornado>=5 in c:\users\admin\anaconda3\lib\site-packages (from distributed>=1.24.2->featuretools) (6.0.3)
# Requirement already satisfied: tblib in c:\users\admin\anaconda3\lib\site-packages (from distributed>=1.24.2->featuretools) (1.4.0)
# Requirement already satisfied: toolz>=0.7.4 in c:\users\admin\anaconda3\lib\site-packages (from distributed>=1.24.2->featuretools) (0.10.0)
# Requirement already satisfied: msgpack in c:\users\admin\anaconda3\lib\site-packages (from distributed>=1.24.2->featuretools) (0.6.1)
# Requirement already satisfied: six in c:\users\admin\anaconda3\lib\site-packages (from distributed>=1.24.2->featuretools) (1.12.0)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in c:\users\admin\anaconda3\lib\site-packages (from distributed>=1.24.2->featuretools) (2.1.0)
# Requirement already satisfied: zict>=0.1.3 in c:\users\admin\anaconda3\lib\site-packages (from distributed>=1.24.2->featuretools) (1.0.0)
# Requirement already satisfied: python-dateutil>=2.5.0 in c:\users\admin\appdata\roaming\python\python37\site-packages (from pandas>=0.24.1->featuretools) (2.6.1)
# Requirement already satisfied: pytz>=2011k in c:\users\admin\anaconda3\lib\site-packages (from pandas>=0.24.1->featuretools) (2019.1)
# Requirement already satisfied: heapdict in c:\users\admin\anaconda3\lib\site-packages (from zict>=0.1.3->distributed>=1.24.2->featuretools) (1.0.0)
# Installing collected packages: featuretools
# Successfully installed featuretools-0.14.0

# %%
import featuretools as ft

# %%
df = pd.read_csv('train_bm.csv')
df.shape
# Out:
# (8523, 12)

# %%
features = df.drop('Item_Outlet_Sales', axis=1)
y = df['Item_Outlet_Sales']

# %%
es = ft.EntitySet(id = 'bigmart')
es
# Out:
# Entityset: bigmart
#   Entities:
#   Relationships:
#     No relationships

# %%
es.entity_from_dataframe(entity_id = 'data_1', dataframe = features,
                        make_index = True, index= 'index')
es
# Out:
# Entityset: bigmart
#   Entities:
#     data_1 [Rows: 8523, Columns: 12]
#   Relationships:
#     No relationships

# %%
feature_matrix, feature_defs = ft.dfs(entityset = es, target_entity ='data_1',max_depth=1,
                                     trans_primitives=['add_numeric','multiply_numeric'])
feature_matrix.head()
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# index
# 0               FDA15         9.30          Low Fat         0.016047
# 1               DRC01         5.92          Regular         0.019278
# 2               FDN15        17.50          Low Fat         0.016760
# 3               FDX07        19.20          Regular         0.000000
# 4               NCD19         8.93          Low Fat         0.000000
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# index
# 0                      Dairy  249.8092            OUT049
# 1                Soft Drinks   48.2692            OUT018
# 2                       Meat  141.6180            OUT049
# 3      Fruits and Vegetables  182.0950            OUT010
# 4                  Household   53.8614            OUT013
#
#        Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  ...  \
# index                                                              ...
# 0                           1999      Medium               Tier 1  ...
# 1                           2009      Medium               Tier 3  ...
# 2                           1999      Medium               Tier 1  ...
# 3                           1998         NaN               Tier 3  ...
# 4                           1987        High               Tier 3  ...
#
#       Item_MRP + Item_Weight  Item_Visibility + Item_Weight  \
# index
# 0                   259.1092                       9.316047
# 1                    54.1892                       5.939278
# 2                   159.1180                      17.516760
# 3                   201.2950                      19.200000
# 4                    62.7914                       8.930000
#
#        Item_Visibility + Outlet_Establishment_Year  \
# index
# 0                                      1999.016047
# 1                                      2009.019278
# 2                                      1999.016760
# 3                                      1998.000000
# 4                                      1987.000000
#
#        Item_MRP + Item_Visibility  Item_MRP * Outlet_Establishment_Year  \
# index
# 0                      249.825247                           499368.5908
# 1                       48.288478                            96972.8228
# 2                      141.634760                           283094.3820
# 3                      182.095000                           363825.8100
# 4                       53.861400                           107022.6018
#
#        Item_Weight * Outlet_Establishment_Year  Item_MRP * Item_Weight  \
# index
# 0                                     18590.70             2323.225560
# 1                                     11893.28              285.753664
# 2                                     34982.50             2478.315000
# 3                                     38361.60             3496.224000
# 4                                     17743.91              480.982302
#
#        Item_Visibility * Item_Weight  \
# index
# 0                           0.149240
# 1                           0.114127
# 2                           0.293301
# 3                           0.000000
# 4                           0.000000
#
#        Item_Visibility * Outlet_Establishment_Year  Item_MRP * Item_Visibility
# index
# 0                                        32.078555                    4.008763
# 1                                        38.729936                    0.930544
# 2                                        33.503390                    2.373528
# 3                                         0.000000                    0.000000
# 4                                         0.000000                    0.000000
#
# [5 rows x 23 columns]

# %%
feature_defs
# Out:
# [<Feature: Item_Identifier>,
#  <Feature: Item_Weight>,
#  <Feature: Item_Fat_Content>,
#  <Feature: Item_Visibility>,
#  <Feature: Item_Type>,
#  <Feature: Item_MRP>,
#  <Feature: Outlet_Identifier>,
#  <Feature: Outlet_Establishment_Year>,
#  <Feature: Outlet_Size>,
#  <Feature: Outlet_Location_Type>,
#  <Feature: Outlet_Type>,
#  <Feature: Item_MRP + Outlet_Establishment_Year>,
#  <Feature: Item_Weight + Outlet_Establishment_Year>,
#  <Feature: Item_MRP + Item_Weight>,
#  <Feature: Item_Visibility + Item_Weight>,
#  <Feature: Item_Visibility + Outlet_Establishment_Year>,
#  <Feature: Item_MRP + Item_Visibility>,
#  <Feature: Item_MRP * Outlet_Establishment_Year>,
#  <Feature: Item_Weight * Outlet_Establishment_Year>,
#  <Feature: Item_MRP * Item_Weight>,
#  <Feature: Item_Visibility * Item_Weight>,
#  <Feature: Item_Visibility * Outlet_Establishment_Year>,
#  <Feature: Item_MRP * Item_Visibility>]

# %%
feature_matrix.shape
# Out:
# (8523, 23)

# %%
feature_matrix, feature_defs = ft.dfs(entityset = es, target_entity ='data_1',max_depth=2,
                                     trans_primitives=['add_numeric','multiply_numeric'])
feature_matrix.head()
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# index
# 0               FDA15         9.30          Low Fat         0.016047
# 1               DRC01         5.92          Regular         0.019278
# 2               FDN15        17.50          Low Fat         0.016760
# 3               FDX07        19.20          Regular         0.000000
# 4               NCD19         8.93          Low Fat         0.000000
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# index
# 0                      Dairy  249.8092            OUT049
# 1                Soft Drinks   48.2692            OUT018
# 2                       Meat  141.6180            OUT049
# 3      Fruits and Vegetables  182.0950            OUT010
# 4                  Household   53.8614            OUT013
#
#        Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  ...  \
# index                                                              ...
# 0                           1999      Medium               Tier 1  ...
# 1                           2009      Medium               Tier 3  ...
# 2                           1999      Medium               Tier 1  ...
# 3                           1998         NaN               Tier 3  ...
# 4                           1987        High               Tier 3  ...
#
#       Item_MRP * Item_Visibility + Outlet_Establishment_Year  \
# index
# 0                                          499372.599563
# 1                                           96973.753344
# 2                                          283096.755528
# 3                                          363825.810000
# 4                                          107022.601800
#
#        Item_Visibility * Item_Visibility + Item_Weight  \
# index
# 0                                             0.149497
# 1                                             0.114499
# 2                                             0.293582
# 3                                             0.000000
# 4                                             0.000000
#
#        Item_MRP + Item_Weight * Item_Weight  \
# index
# 0                               2409.715560
# 1                                320.800064
# 2                               2784.565000
# 3                               3864.864000
# 4                                560.727202
#
#        Item_MRP + Item_Visibility * Item_Weight  \
# index
# 0                                   2323.374800
# 1                                    285.867791
# 2                                   2478.608301
# 3                                   3496.224000
# 4                                    480.982302
#
#        Item_Visibility + Outlet_Establishment_Year * Item_Weight  \
# index
# 0                                           18590.849240
# 1                                           11893.394127
# 2                                           34982.793301
# 3                                           38361.600000
# 4                                           17743.910000
#
#        Item_MRP + Item_Weight * Item_Weight + Outlet_Establishment_Year  \
# index
# 0                                          520369.006360
# 1                                          109186.902864
# 2                                          320861.447000
# 3                                          406052.274000
# 4                                          125327.239002
#
#        Item_MRP + Item_Visibility * Item_Visibility  \
# index
# 0                                          4.009021
# 1                                          0.930916
# 2                                          2.373809
# 3                                          0.000000
# 4                                          0.000000
#
#        Item_MRP + Outlet_Establishment_Year * Item_Visibility + Item_Weight  \
# index
# 0                                           20950.012878
# 1                                           12218.694144
# 2                                           37496.691918
# 3                                           41857.824000
# 4                                           18224.892302
#
#        Item_MRP + Item_Weight * Item_Visibility + Outlet_Establishment_Year  \
# index
# 0                                          517963.448803
# 1                                          108867.147471
# 2                                          318079.548830
# 3                                          402187.410000
# 4                                          124766.511800
#
#        Item_MRP + Item_Visibility * Outlet_Establishment_Year
# index
# 0                                          499400.669355
# 1                                           97011.552736
# 2                                          283127.885390
# 3                                          363825.810000
# 4                                          107022.601800
#
# [5 rows x 62 columns]

# %%
feature_matrix.shape
# Out:
# (8523, 62)
