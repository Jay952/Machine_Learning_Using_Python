# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('chennai_house_price_prediction.csv')

# %%
df.plot().hist
# Out:
# <bound method Axes.hist of <matplotlib.axes._subplots.AxesSubplot object at 0x000001FB96301128>>

# %%
df.shape
# Out:
# (7109, 19)

# %%
df.head()
# Out:
#    PRT_ID        AREA  INT_SQFT  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  N_ROOM  \
# 0  P03210  Karapakkam      1004            131        1.0         1.0       3
# 1  P09411  Anna Nagar      1986             26        2.0         1.0       5
# 2  P01812       Adyar       909             70        1.0         1.0       3
# 3  P05346   Velachery      1855             14        3.0         2.0       5
# 4  P06210  Karapakkam      1226             84        1.0         1.0       3
#
#   SALE_COND PARK_FACIL   BUILDTYPE UTILITY_AVAIL  STREET MZZONE  QS_ROOMS  \
# 0  AbNormal        Yes  Commercial        AllPub   Paved      A       4.0
# 1  AbNormal         No  Commercial        AllPub  Gravel     RH       4.9
# 2  AbNormal        Yes  Commercial           ELO  Gravel     RL       4.1
# 3    Family         No      Others       NoSewr    Paved      I       4.7
# 4  AbNormal        Yes      Others        AllPub  Gravel      C       3.0
#
#    QS_BATHROOM  QS_BEDROOM  QS_OVERALL  COMMIS  SALES_PRICE
# 0          3.9         4.9       4.330  144400      7600000
# 1          4.2         2.5       3.765  304049     21717770
# 2          3.8         2.2       3.090   92114     13159200
# 3          3.9         3.6       4.010   77042      9630290
# 4          2.5         4.1       3.290   74063      7406250

# %%
df.describe()
# Out:
#           INT_SQFT  DIST_MAINROAD    N_BEDROOM   N_BATHROOM       N_ROOM  \
# count  7109.000000    7109.000000  7108.000000  7104.000000  7109.000000
# mean   1382.073006      99.603179     1.637029     1.213260     3.688704
# std     457.410902      57.403110     0.802902     0.409639     1.019099
# min     500.000000       0.000000     1.000000     1.000000     2.000000
# 25%     993.000000      50.000000     1.000000     1.000000     3.000000
# 50%    1373.000000      99.000000     1.000000     1.000000     4.000000
# 75%    1744.000000     148.000000     2.000000     1.000000     4.000000
# max    2500.000000     200.000000     4.000000     2.000000     6.000000
#
#           QS_ROOMS  QS_BATHROOM   QS_BEDROOM   QS_OVERALL         COMMIS  \
# count  7109.000000  7109.000000  7109.000000  7061.000000    7109.000000
# mean      3.517471     3.507244     3.485300     3.503254  141005.726544
# std       0.891972     0.897834     0.887266     0.527223   78768.093718
# min       2.000000     2.000000     2.000000     2.000000    5055.000000
# 25%       2.700000     2.700000     2.700000     3.130000   84219.000000
# 50%       3.500000     3.500000     3.500000     3.500000  127628.000000
# 75%       4.300000     4.300000     4.300000     3.890000  184506.000000
# max       5.000000     5.000000     5.000000     4.970000  495405.000000
#
#         SALES_PRICE
# count  7.109000e+03
# mean   1.089491e+07
# std    3.768603e+06
# min    2.156875e+06
# 25%    8.272100e+06
# 50%    1.033505e+07
# 75%    1.299390e+07
# max    2.366734e+07

# %%
df.describe(include = 'all')
# Out:
#         PRT_ID      AREA     INT_SQFT  DIST_MAINROAD    N_BEDROOM  \
# count     7109      7109  7109.000000    7109.000000  7108.000000
# unique    7109        17          NaN            NaN          NaN
# top     P08908  Chrompet          NaN            NaN          NaN
# freq         1      1681          NaN            NaN          NaN
# mean       NaN       NaN  1382.073006      99.603179     1.637029
# std        NaN       NaN   457.410902      57.403110     0.802902
# min        NaN       NaN   500.000000       0.000000     1.000000
# 25%        NaN       NaN   993.000000      50.000000     1.000000
# 50%        NaN       NaN  1373.000000      99.000000     1.000000
# 75%        NaN       NaN  1744.000000     148.000000     2.000000
# max        NaN       NaN  2500.000000     200.000000     4.000000
#
#          N_BATHROOM       N_ROOM SALE_COND PARK_FACIL BUILDTYPE UTILITY_AVAIL  \
# count   7104.000000  7109.000000      7109       7109      7109          7109
# unique          NaN          NaN         9          3         5             5
# top             NaN          NaN   AdjLand        Yes     House        AllPub
# freq            NaN          NaN      1433       3587      2444          1886
# mean       1.213260     3.688704       NaN        NaN       NaN           NaN
# std        0.409639     1.019099       NaN        NaN       NaN           NaN
# min        1.000000     2.000000       NaN        NaN       NaN           NaN
# 25%        1.000000     3.000000       NaN        NaN       NaN           NaN
# 50%        1.000000     4.000000       NaN        NaN       NaN           NaN
# 75%        1.000000     4.000000       NaN        NaN       NaN           NaN
# max        2.000000     6.000000       NaN        NaN       NaN           NaN
#
#        STREET MZZONE     QS_ROOMS  QS_BATHROOM   QS_BEDROOM   QS_OVERALL  \
# count    7109   7109  7109.000000  7109.000000  7109.000000  7061.000000
# unique      5      6          NaN          NaN          NaN          NaN
# top     Paved     RL          NaN          NaN          NaN          NaN
# freq     2560   1858          NaN          NaN          NaN          NaN
# mean      NaN    NaN     3.517471     3.507244     3.485300     3.503254
# std       NaN    NaN     0.891972     0.897834     0.887266     0.527223
# min       NaN    NaN     2.000000     2.000000     2.000000     2.000000
# 25%       NaN    NaN     2.700000     2.700000     2.700000     3.130000
# 50%       NaN    NaN     3.500000     3.500000     3.500000     3.500000
# 75%       NaN    NaN     4.300000     4.300000     4.300000     3.890000
# max       NaN    NaN     5.000000     5.000000     5.000000     4.970000
#
#                COMMIS   SALES_PRICE
# count     7109.000000  7.109000e+03
# unique            NaN           NaN
# top               NaN           NaN
# freq              NaN           NaN
# mean    141005.726544  1.089491e+07
# std      78768.093718  3.768603e+06
# min       5055.000000  2.156875e+06
# 25%      84219.000000  8.272100e+06
# 50%     127628.000000  1.033505e+07
# 75%     184506.000000  1.299390e+07
# max     495405.000000  2.366734e+07

# %%
df.isnull().sum()
# Out:
# PRT_ID            0
# AREA              0
# INT_SQFT          0
# DIST_MAINROAD     0
# N_BEDROOM         1
# N_BATHROOM        5
# N_ROOM            0
# SALE_COND         0
# PARK_FACIL        0
# BUILDTYPE         0
# UTILITY_AVAIL     0
# STREET            0
# MZZONE            0
# QS_ROOMS          0
# QS_BATHROOM       0
# QS_BEDROOM        0
# QS_OVERALL       48
# COMMIS            0
# SALES_PRICE       0
# dtype: int64

# %%
df.dtypes
# Out:
# PRT_ID            object
# AREA              object
# INT_SQFT           int64
# DIST_MAINROAD      int64
# N_BEDROOM        float64
# N_BATHROOM       float64
# N_ROOM             int64
# SALE_COND         object
# PARK_FACIL        object
# BUILDTYPE         object
# UTILITY_AVAIL     object
# STREET            object
# MZZONE            object
# QS_ROOMS         float64
# QS_BATHROOM      float64
# QS_BEDROOM       float64
# QS_OVERALL       float64
# COMMIS             int64
# SALES_PRICE        int64
# dtype: object

# %%
temp = pd.DataFrame(index = df.columns)
temp['data_type'] = df.dtypes
temp['null_count'] = df.isnull().sum()
temp['unique_count'] = df.nunique()

# %%
temp
# Out:
#               data_type  null_count  unique_count
# PRT_ID           object           0          7109
# AREA             object           0            17
# INT_SQFT          int64           0          1699
# DIST_MAINROAD     int64           0           201
# N_BEDROOM       float64           1             4
# N_BATHROOM      float64           5             2
# N_ROOM            int64           0             5
# SALE_COND        object           0             9
# PARK_FACIL       object           0             3
# BUILDTYPE        object           0             5
# UTILITY_AVAIL    object           0             5
# STREET           object           0             5
# MZZONE           object           0             6
# QS_ROOMS        float64           0            31
# QS_BATHROOM     float64           0            31
# QS_BEDROOM      float64           0            31
# QS_OVERALL      float64          48           479
# COMMIS            int64           0          7011
# SALES_PRICE       int64           0          7057

# %%
df['SALES_PRICE'].plot.hist(bins = 50)

# %%
df['SALES_PRICE'].loc[df['SALES_PRICE'] < 18000000].plot.hist(bins = 50)

# %%
df['INT_SQFT'].plot.hist(bins = 50)
plt.xlabel('Area in sq. feet', fontsize=12)
# Out:
# Text(0.5, 0, 'Area in sq. feet')

# %%
df['N_BEDROOM'].value_counts()
# Out:
# 1.0    3795
# 2.0    2352
# 3.0     707
# 4.0     254
# Name: N_BEDROOM, dtype: int64

# %%
df['N_BEDROOM'].value_counts()/len(df)
# Out:
# 1.0    0.533830
# 2.0    0.330848
# 3.0    0.099451
# 4.0    0.035729
# Name: N_BEDROOM, dtype: float64

# %%
df['N_ROOM'].value_counts()
# Out:
# 4    2563
# 3    2125
# 5    1246
# 2     921
# 6     254
# Name: N_ROOM, dtype: int64

# %%
df['N_BATHROOM'].value_counts()/len(df)
# Out:
# 1.0    0.786187
# 2.0    0.213110
# Name: N_BATHROOM, dtype: float64

# %%
df['N_BATHROOM'].value_counts().plot(kind = 'bar')

# %%
df['AREA'].value_counts().plot(kind = 'bar')

# %%
df['PARK_FACIL'].value_counts().plot(kind = 'bar')

# %%
df.drop_duplicates()
# Out:
#       PRT_ID        AREA  INT_SQFT  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  \
# 0     P03210  Karapakkam      1004            131        1.0         1.0
# 1     P09411  Anna Nagar      1986             26        2.0         1.0
# 2     P01812       Adyar       909             70        1.0         1.0
# 3     P05346   Velachery      1855             14        3.0         2.0
# 4     P06210  Karapakkam      1226             84        1.0         1.0
# 5     P00219    Chrompet      1220             36        2.0         1.0
# 6     P09105    Chrompet      1167            137        1.0         1.0
# 7     P09679   Velachery      1847            176        3.0         2.0
# 8     P03377    Chrompet       771            175        1.0         1.0
# 9     P09623   Velachery      1635             74        2.0         1.0
# 10    P09540    Chrompet      1203             78        2.0         1.0
# 11    P07121    Chrompet      1054            143        1.0         1.0
# 12    P05512    Chrompet      1196            137        1.0         1.0
# 13    P09370       Adyar      1056             83        1.0         1.0
# 14    P04085   Velachery      1865            157        3.0         2.0
# 15    P06328   Velachery      1868            148        3.0         2.0
# 16    P06039  Karapakkam      1639            175        2.0         2.0
# 17    P02016    Chrompet       796            134        1.0         1.0
# 18    P08160       Adyar      1136             69        1.0         1.0
# 19    P01372  Anna Nagar      1902            168        2.0         1.0
# 20    P00936    Chrompet      1069             53        1.0         1.0
# 21    P07346    Chrompet       931             96        1.0         1.0
# 22    P06851    KK Nagar      2010            114        3.0         2.0
# 23    P04665    Chrompet      1074            100        1.0         1.0
# 24    P00902      TNagar      1972            111        2.0         1.0
# 25    P00293     T Nagar      1685            105        1.0         1.0
# 26    P02235       Adyar      1130             29        1.0         1.0
# 27    P04080  Karapakkam      1301             59        1.0         1.0
# 28    P02677       Adyar       730            185        1.0         1.0
# 29    P00755     T Nagar      1806            138        2.0         1.0
# ...      ...         ...       ...            ...        ...         ...
# 7079  P01918       Adyar       934             91        1.0         1.0
# 7080  P08039       Adyar       903            108        1.0         1.0
# 7081  P00603     T Nagar      1946            148        2.0         1.0
# 7082  P08060       Adyar       791             71        1.0         1.0
# 7083  P09758   Velachery      1992            147        3.0         2.0
# 7084  P07245    Chrompet       858             32        1.0         1.0
# 7085  P08537    Chrompet       990            181        1.0         1.0
# 7086  P03059  Karapakkam       705            100        1.0         1.0
# 7087  P05763  Karapakkam      1008            194        1.0         1.0
# 7088  P05164  Karapakkam      1696             48        2.0         2.0
# 7089  P06915   Velachery      1907             86        3.0         2.0
# 7090  P02629    KK Nagar      1960             98        3.0         2.0
# 7091  P03495    KK Nagar      2051             30        3.0         2.0
# 7092  P00465    Chrompet      1202            134        2.0         1.0
# 7093  P07282   Velachery      1941             90        3.0         2.0
# 7094  P07645    KK Nagar      2456            171        4.0         2.0
# 7095  P08967  Anna Nagar      1955             33        2.0         1.0
# 7096  P03146    Chrompet      1275              3        2.0         1.0
# 7097  P05670  Anna Nagar      1860            174        2.0         1.0
# 7098  P00629  Anna Nagar      1611            144        1.0         1.0
# 7099  P03828       Adyar       895            197        1.0         1.0
# 7100  P05438     T Nagar      1733            191        1.0         1.0
# 7101  P05042  Karapakkam       666             51        1.0         1.0
# 7102  P05560  Karapakkam       701            100        1.0         1.0
# 7103  P05133  Karapakkam      1462             68        2.0         2.0
# 7104  P03834  Karapakkam       598             51        1.0         1.0
# 7105  P10000   Velachery      1897             52        3.0         2.0
# 7106  P09594   Velachery      1614            152        2.0         1.0
# 7107  P06508  Karapakkam       787             40        1.0         1.0
# 7108  P09794   Velachery      1896            156        3.0         2.0
#
#       N_ROOM    SALE_COND PARK_FACIL   BUILDTYPE UTILITY_AVAIL     STREET  \
# 0          3     AbNormal        Yes  Commercial        AllPub      Paved
# 1          5     AbNormal         No  Commercial        AllPub     Gravel
# 2          3     AbNormal        Yes  Commercial           ELO     Gravel
# 3          5       Family         No      Others       NoSewr       Paved
# 4          3     AbNormal        Yes      Others        AllPub     Gravel
# 5          4      Partial         No  Commercial        NoSeWa  No Access
# 6          3      Partial         No       Other        AllPub  No Access
# 7          5       Family         No  Commercial        AllPub     Gravel
# 8          2      AdjLand         No      Others       NoSewr       Paved
# 9          4     AbNormal         No      Others           ELO  No Access
# 10         4      AdjLand        Yes  Commercial        AllPub  No Access
# 11         3      Partial         No      Others       NoSewr      Gravel
# 12         3       Family         No      Others       NoSewr   No Access
# 13         3      Partial        Yes      Others       NoSewr       Paved
# 14         5       Family         No  Commercial       NoSewr       Paved
# 15         5       Family         No  Commercial       NoSewr      Gravel
# 16         4  Normal Sale        Yes       House           ELO     Gravel
# 17         2      AdjLand        Yes  Commercial        AllPub  No Access
# 18         3  Normal Sale        Yes      Others        AllPub      Paved
# 19         5       Family        Yes  Commercial           ELO      Paved
# 20         3     AbNormal        Yes      Others       NoSewr       Paved
# 21         3     AbNormal        Yes      Others           ELO      Paved
# 22         5      Partial         No      Others       NoSewr      Gravel
# 23         3     AbNormal         No      Others       NoSewr      Gravel
# 24         5      AdjLand         No      Others       NoSewr   No Access
# 25         4       Family         No       House       NoSewr      Gravel
# 26         3       Family        Yes  Commercial           ELO      Paved
# 27         3  Normal Sale        Yes      Others       NoSewr      Gravel
# 28         2      AdjLand        Yes       House           ELO     Gravel
# 29         5       Family         No       House        NoSeWa      Paved
# ...      ...          ...        ...         ...           ...        ...
# 7079       3     AbNormal         No      Others        NoSeWa      Paved
# 7080       3     AbNormal        Yes       House       NoSewr       Paved
# 7081       5      AdjLand         No      Others        NoSeWa     Gravel
# 7082       2      Partial        Yes  Commercial        NoSeWa     Gravel
# 7083       5      Partial         No       House        NoSeWa     Gravel
# 7084       3      Partial        Yes       House        NoSeWa  No Access
# 7085       3     AbNormal         No  Commercial           ELO      Paved
# 7086       2       Family        Yes       House           ELO     Gravel
# 7087       3      Partial        Yes  Commercial        NoSeWa  No Access
# 7088       4  Normal Sale         No       House       NoSewr   No Access
# 7089       5  Normal Sale         No  Commercial           ELO      Paved
# 7090       5  Normal Sale         No      Others       NoSewr       Paved
# 7091       5      Partial         No       House       NoSewr      Gravel
# 7092       4       Family         No      Others       NoSewr       Paved
# 7093       5     AbNormal        Yes       House           ELO  No Access
# 7094       6      AdjLand        Yes       House       NoSewr      Gravel
# 7095       5       Family         No       House       NoSewr       Paved
# 7096       4     AbNormal         No       House           ELO     Gravel
# 7097       5     AbNormal         No      Others        AllPub     Gravel
# 7098       4      Partial        Yes      Others        NoSeWa      Paved
# 7099       3      AdjLand        Yes       House       NoSewr   No Access
# 7100       4     AbNormal        Yes  Commercial        NoSeWa  No Access
# 7101       2      AdjLand        Yes      Others           ELO     Gravel
# 7102       2     AbNormal         No       House        NoSeWa     Gravel
# 7103       4       Family         No      Others        NoSeWa     Gravel
# 7104       2      AdjLand         No      Others           ELO  No Access
# 7105       5       Family        Yes      Others        NoSeWa  No Access
# 7106       4  Normal Sale         No       House        NoSeWa     Gravel
# 7107       2      Partial        Yes  Commercial           ELO      Paved
# 7108       5      Partial        Yes      Others           ELO      Paved
#
#      MZZONE  QS_ROOMS  QS_BATHROOM  QS_BEDROOM  QS_OVERALL  COMMIS  \
# 0         A       4.0          3.9         4.9       4.330  144400
# 1        RH       4.9          4.2         2.5       3.765  304049
# 2        RL       4.1          3.8         2.2       3.090   92114
# 3         I       4.7          3.9         3.6       4.010   77042
# 4         C       3.0          2.5         4.1       3.290   74063
# 5        RH       4.5          2.6         3.1       3.320  198316
# 6        RL       3.6          2.1         2.5       2.670   33955
# 7        RM       2.4          4.5         2.1       3.260  235204
# 8        RM       2.9          3.7         4.0       3.550   33236
# 9         I       3.1          3.1         3.3       3.160  121255
# 10       RM       4.0          3.2         4.5       3.830  119504
# 11       RM       2.2          3.1         3.3       2.890  141746
# 12       RL       2.1          2.5         2.1       2.260   35097
# 13       RH       2.2          3.4         3.7       3.190   37546
# 14       RM       4.8          2.2         4.9       3.660  294494
# 15       RH       3.8          3.8         3.1         NaN  188569
# 16        I       2.3          3.2         4.8       3.570   77904
# 17       RL       3.5          4.6         4.7       4.300  130951
# 18        A       4.6          2.6         2.9       3.350   49725
# 19       RL       4.5          4.9         4.9       4.760  212032
# 20       RM       2.8          2.7         4.9       3.390   43622
# 21       RL       4.2          3.1         3.1       3.430   27558
# 22       RH       3.4          4.5         3.4       3.730  262210
# 23       RL       3.0          3.4         4.9       3.730   86646
# 24       RH       4.1          4.4         2.8       3.590  167073
# 25       RM       2.8          4.4         4.0       3.740  176415
# 26       RH       2.3          2.5         2.2       2.290   53533
# 27        C       2.8          2.7         3.8       3.170   71457
# 28       RL       2.7          4.6         4.9       4.180   53090
# 29       RH       4.1          5.0         3.0       3.830  113382
# ...     ...       ...          ...         ...         ...     ...
# 7079     RH       2.6          4.8         2.0       2.740  104227
# 7080      C       4.8          4.4         4.0       4.320   68502
# 7081     RH       2.7          3.8         2.9       3.065  171371
# 7082      C       4.9          3.8         4.2       4.330  146742
# 7083     RM       2.4          2.8         2.4       2.580  111291
# 7084     RL       2.9          3.0         3.9       3.240   30174
# 7085     RL       3.0          4.2         4.8       4.020  203252
# 7086      A       4.7          3.1         4.8       4.260   59641
# 7087     RL       2.5          4.5         3.4       3.460  200646
# 7088     RH       4.9          4.9         5.0       4.940   57312
# 7089      C       2.4          4.0         4.3       3.690  210380
# 7090     RL       5.0          3.7         3.3       3.930  122051
# 7091     RM       3.0          2.1         4.4       3.290  160131
# 7092     RH       3.1          3.4         3.5       3.340   25831
# 7093     RH       3.4          4.6         3.7       4.030  141304
# 7094     RM       5.0          5.0         3.0       4.200  353880
# 7095     RM       3.7          3.4         2.8       3.265  146396
# 7096     RL       3.9          3.8         4.1       3.920   86339
# 7097     RH       4.6          3.4         3.2       3.740   70557
# 7098     RM       3.2          3.7         2.9       3.205  209172
# 7099      I       3.6          4.7         4.2       4.120    7372
# 7100     RL       3.4          3.7         2.1       2.890  312026
# 7101      I       3.2          4.4         2.5       3.280   74541
# 7102     RH       4.2          3.0         2.0       2.960  141088
# 7103     RM       2.7          3.3         3.6       3.240  178358
# 7104     RM       3.0          2.2         2.4       2.520  107060
# 7105     RH       3.6          4.5         3.3       3.920  205551
# 7106      I       4.3          4.2         2.9       3.840  167028
# 7107     RL       4.6          3.8         4.1       4.160  119098
# 7108      I       3.1          3.5         4.3       3.640   79812
#
#       SALES_PRICE
# 0         7600000
# 1        21717770
# 2        13159200
# 3         9630290
# 4         7406250
# 5        12394750
# 6         8488790
# 7        16800250
# 8         8308970
# 9         8083650
# 10       14938000
# 11        9449730
# 12        8774370
# 13        9386490
# 14       15499680
# 15       15714080
# 16        8656000
# 17       10912550
# 18        8287550
# 19       21203240
# 20       10905530
# 21        9185970
# 22       10925400
# 23        9627380
# 24       13922760
# 25       12601080
# 26       13383350
# 27        7939625
# 28        8848285
# 29       11338200
# ...           ...
# 7079      8017445
# 7080      7611350
# 7081     14280890
# 7082      9782785
# 7083     11129100
# 7084      7543400
# 7085     11956000
# 7086      4587750
# 7087      9120250
# 7088      7164000
# 7089     14025340
# 7090     11095520
# 7091     11437920
# 7092      8610340
# 7093      9420260
# 7094     14155200
# 7095     13308750
# 7096      9593250
# 7097     14111320
# 7098     13944780
# 7099      7371800
# 7100     19501600
# 7101      6211750
# 7102      5643500
# 7103      9387250
# 7104      5353000
# 7105     10818480
# 7106      8351410
# 7107      8507000
# 7108      9976480
#
# [7109 rows x 19 columns]

# %%
df.drop_duplicates(subset = ['AREA'])
# Out:
#       PRT_ID        AREA  INT_SQFT  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  \
# 0     P03210  Karapakkam      1004            131        1.0         1.0
# 1     P09411  Anna Nagar      1986             26        2.0         1.0
# 2     P01812       Adyar       909             70        1.0         1.0
# 3     P05346   Velachery      1855             14        3.0         2.0
# 5     P00219    Chrompet      1220             36        2.0         1.0
# 22    P06851    KK Nagar      2010            114        3.0         2.0
# 24    P00902      TNagar      1972            111        2.0         1.0
# 25    P00293     T Nagar      1685            105        1.0         1.0
# 175   P00920     Chrompt       869             39        1.0         1.0
# 245   P00166     Chrmpet      1277            111        2.0         1.0
# 587   P06395   Karapakam       520            130        1.0         1.0
# 855   P00659   Ana Nagar      1894            189        2.0         1.0
# 1132  P01455    Chormpet       991            105        1.0         1.0
# 1442  P09422        Adyr       784             17        1.0         1.0
# 3817  P09948    Velchery      1696            189        2.0         1.0
# 4417  P00137   Ann Nagar      1704            133        1.0         1.0
# 7074  P06491     KKNagar      1521             14        2.0         1.0
#
#       N_ROOM SALE_COND PARK_FACIL   BUILDTYPE UTILITY_AVAIL     STREET MZZONE  \
# 0          3  AbNormal        Yes  Commercial        AllPub      Paved      A
# 1          5  AbNormal         No  Commercial        AllPub     Gravel     RH
# 2          3  AbNormal        Yes  Commercial           ELO     Gravel     RL
# 3          5    Family         No      Others       NoSewr       Paved      I
# 5          4   Partial         No  Commercial        NoSeWa  No Access     RH
# 22         5   Partial         No      Others       NoSewr      Gravel     RH
# 24         5   AdjLand         No      Others       NoSewr   No Access     RH
# 25         4    Family         No       House       NoSewr      Gravel     RM
# 175        3    Family         No      Others       NoSewr   No Access     RM
# 245        4   AdjLand        Yes  Commercial        AllPub  No Access     RM
# 587        2   Partial         No       House           ELO      Paved     RL
# 855        5   AdjLand        Yes      Others           ELO  No Access     RL
# 1132       3   AdjLand         No       House        NoSeWa      Paved     RM
# 1442       2   AdjLand         No       House       NoSewr      Gravel     RM
# 3817       4   Partial         No  Commercial           ELO     Gravel      I
# 4417       4   Partial        Yes       House       NoSewr   No Access     RH
# 7074       4  Adj Land         No  Commercial        NoSeWa     Gravel     RH
#
#       QS_ROOMS  QS_BATHROOM  QS_BEDROOM  QS_OVERALL  COMMIS  SALES_PRICE
# 0          4.0          3.9         4.9       4.330  144400      7600000
# 1          4.9          4.2         2.5       3.765  304049     21717770
# 2          4.1          3.8         2.2       3.090   92114     13159200
# 3          4.7          3.9         3.6       4.010   77042      9630290
# 5          4.5          2.6         3.1       3.320  198316     12394750
# 22         3.4          4.5         3.4       3.730  262210     10925400
# 24         4.1          4.4         2.8       3.590  167073     13922760
# 25         2.8          4.4         4.0       3.740  176415     12601080
# 175        4.3          4.8         3.3       4.200  138935      8172630
# 245        4.0          3.8         3.4       3.740   47131     15710400
# 587        3.7          4.2         3.9       3.930   82433      4849000
# 855        5.0          5.0         3.9       4.560  243277     14310420
# 1132       2.2          4.8         4.6       3.960   52590      8765000
# 1442       4.8          2.0         2.6       3.140   90440      9044045
# 3817       3.4          2.7         3.1       3.000  163136     13594630
# 4417       2.0          2.7         2.2       2.255  102367     11374070
# 7074       3.8          2.4         3.1       3.100  327926     13117020

# %%
df.drop_duplicates(subset = ['AREA']).shape
# Out:
# (17, 19)

# %%
df.isnull().sum()
# Out:
# PRT_ID            0
# AREA              0
# INT_SQFT          0
# DIST_MAINROAD     0
# N_BEDROOM         1
# N_BATHROOM        5
# N_ROOM            0
# SALE_COND         0
# PARK_FACIL        0
# BUILDTYPE         0
# UTILITY_AVAIL     0
# STREET            0
# MZZONE            0
# QS_ROOMS          0
# QS_BATHROOM       0
# QS_BEDROOM        0
# QS_OVERALL       48
# COMMIS            0
# SALES_PRICE       0
# dtype: int64

# %%
df.dropna(axis = 0, how ='any')
# Out:
#       PRT_ID        AREA  INT_SQFT  DIST_MAINROAD N_BEDROOM N_BATHROOM N_ROOM  \
# 0     P03210  Karapakkam      1004            131         1          1      3
# 1     P09411  Anna Nagar      1986             26         2          1      5
# 2     P01812       Adyar       909             70         1          1      3
# 3     P05346   Velachery      1855             14         3          2      5
# 4     P06210  Karapakkam      1226             84         1          1      3
# 5     P00219    Chrompet      1220             36         2          1      4
# 6     P09105    Chrompet      1167            137         1          1      3
# 7     P09679   Velachery      1847            176         3          2      5
# 8     P03377    Chrompet       771            175         1          1      2
# 9     P09623   Velachery      1635             74         2          1      4
# 10    P09540    Chrompet      1203             78         2          1      4
# 11    P07121    Chrompet      1054            143         1          1      3
# 12    P05512    Chrompet      1196            137         1          1      3
# 13    P09370       Adyar      1056             83         1          1      3
# 14    P04085   Velachery      1865            157         3          2      5
# 15    P06328   Velachery      1868            148         3          2      5
# 16    P06039  Karapakkam      1639            175         2          2      4
# 17    P02016    Chrompet       796            134         1          1      2
# 18    P08160       Adyar      1136             69         1          1      3
# 19    P01372  Anna Nagar      1902            168         2          1      5
# 20    P00936    Chrompet      1069             53         1          1      3
# 21    P07346    Chrompet       931             96         1          1      3
# 22    P06851    KK Nagar      2010            114         3          2      5
# 23    P04665    Chrompet      1074            100         1          1      3
# 24    P00902     T Nagar      1972            111         2          1      5
# 25    P00293     T Nagar      1685            105         1          1      4
# 26    P02235       Adyar      1130             29         1          1      3
# 27    P04080  Karapakkam      1301             59         1          1      3
# 28    P02677       Adyar       730            185         1          1      2
# 29    P00755     T Nagar      1806            138         2          1      5
# ...      ...         ...       ...            ...       ...        ...    ...
# 7079  P01918       Adyar       934             91         1          1      3
# 7080  P08039       Adyar       903            108         1          1      3
# 7081  P00603     T Nagar      1946            148         2          1      5
# 7082  P08060       Adyar       791             71         1          1      2
# 7083  P09758   Velachery      1992            147         3          2      5
# 7084  P07245    Chrompet       858             32         1          1      3
# 7085  P08537    Chrompet       990            181         1          1      3
# 7086  P03059  Karapakkam       705            100         1          1      2
# 7087  P05763  Karapakkam      1008            194         1          1      3
# 7088  P05164  Karapakkam      1696             48         2          2      4
# 7089  P06915   Velachery      1907             86         3          2      5
# 7090  P02629    KK Nagar      1960             98         3          2      5
# 7091  P03495    KK Nagar      2051             30         3          2      5
# 7092  P00465    Chrompet      1202            134         2          1      4
# 7093  P07282   Velachery      1941             90         3          2      5
# 7094  P07645    KK Nagar      2456            171         4          2      6
# 7095  P08967  Anna Nagar      1955             33         2          1      5
# 7096  P03146    Chrompet      1275              3         2          1      4
# 7097  P05670  Anna Nagar      1860            174         2          1      5
# 7098  P00629  Anna Nagar      1611            144         1          1      4
# 7099  P03828       Adyar       895            197         1          1      3
# 7100  P05438     T Nagar      1733            191         1          1      4
# 7101  P05042  Karapakkam       666             51         1          1      2
# 7102  P05560  Karapakkam       701            100         1          1      2
# 7103  P05133  Karapakkam      1462             68         2          2      4
# 7104  P03834  Karapakkam       598             51         1          1      2
# 7105  P10000   Velachery      1897             52         3          2      5
# 7106  P09594   Velachery      1614            152         2          1      4
# 7107  P06508  Karapakkam       787             40         1          1      2
# 7108  P09794   Velachery      1896            156         3          2      5
#
#         SALE_COND PARK_FACIL   BUILDTYPE UTILITY_AVAIL     STREET MZZONE  \
# 0        AbNormal        Yes  Commercial        AllPub      Paved      A
# 1        AbNormal         No  Commercial        AllPub     Gravel     RH
# 2        AbNormal        Yes  Commercial           ELO     Gravel     RL
# 3          Family         No      Others       NoSewr       Paved      I
# 4        AbNormal        Yes      Others        AllPub     Gravel      C
# 5         Partial         No  Commercial        NoSeWa  No Access     RH
# 6         Partial         No       Other        AllPub  No Access     RL
# 7          Family         No  Commercial        AllPub     Gravel     RM
# 8         AdjLand         No      Others       NoSewr       Paved     RM
# 9        AbNormal         No      Others           ELO  No Access      I
# 10        AdjLand        Yes  Commercial        AllPub  No Access     RM
# 11        Partial         No      Others       NoSewr      Gravel     RM
# 12         Family         No      Others       NoSewr   No Access     RL
# 13        Partial        Yes      Others       NoSewr       Paved     RH
# 14         Family         No  Commercial       NoSewr       Paved     RM
# 15         Family         No  Commercial       NoSewr      Gravel     RH
# 16    Normal Sale        Yes       House           ELO     Gravel      I
# 17        AdjLand        Yes  Commercial        AllPub  No Access     RL
# 18    Normal Sale        Yes      Others        AllPub      Paved      A
# 19         Family        Yes  Commercial           ELO      Paved     RL
# 20       AbNormal        Yes      Others       NoSewr       Paved     RM
# 21       AbNormal        Yes      Others           ELO      Paved     RL
# 22        Partial         No      Others       NoSewr      Gravel     RH
# 23       AbNormal         No      Others       NoSewr      Gravel     RL
# 24        AdjLand         No      Others       NoSewr   No Access     RH
# 25         Family         No       House       NoSewr      Gravel     RM
# 26         Family        Yes  Commercial           ELO      Paved     RH
# 27    Normal Sale        Yes      Others       NoSewr      Gravel      C
# 28        AdjLand        Yes       House           ELO     Gravel     RL
# 29         Family         No       House        NoSeWa      Paved     RH
# ...           ...        ...         ...           ...        ...    ...
# 7079     AbNormal         No      Others        NoSeWa      Paved     RH
# 7080     AbNormal        Yes       House       NoSewr       Paved      C
# 7081      AdjLand         No      Others        NoSeWa     Gravel     RH
# 7082      Partial        Yes  Commercial        NoSeWa     Gravel      C
# 7083      Partial         No       House        NoSeWa     Gravel     RM
# 7084      Partial        Yes       House        NoSeWa  No Access     RL
# 7085     AbNormal         No  Commercial           ELO      Paved     RL
# 7086       Family        Yes       House           ELO     Gravel      A
# 7087      Partial        Yes  Commercial        NoSeWa  No Access     RL
# 7088  Normal Sale         No       House       NoSewr   No Access     RH
# 7089  Normal Sale         No  Commercial           ELO      Paved      C
# 7090  Normal Sale         No      Others       NoSewr       Paved     RL
# 7091      Partial         No       House       NoSewr      Gravel     RM
# 7092       Family         No      Others       NoSewr       Paved     RH
# 7093     AbNormal        Yes       House           ELO  No Access     RH
# 7094      AdjLand        Yes       House       NoSewr      Gravel     RM
# 7095       Family         No       House       NoSewr       Paved     RM
# 7096     AbNormal         No       House           ELO     Gravel     RL
# 7097     AbNormal         No      Others        AllPub     Gravel     RH
# 7098      Partial        Yes      Others        NoSeWa      Paved     RM
# 7099      AdjLand        Yes       House       NoSewr   No Access      I
# 7100     AbNormal        Yes  Commercial        NoSeWa  No Access     RL
# 7101      AdjLand        Yes      Others           ELO     Gravel      I
# 7102     AbNormal         No       House        NoSeWa     Gravel     RH
# 7103       Family         No      Others        NoSeWa     Gravel     RM
# 7104      AdjLand         No      Others           ELO  No Access     RM
# 7105       Family        Yes      Others        NoSeWa  No Access     RH
# 7106  Normal Sale         No       House        NoSeWa     Gravel      I
# 7107      Partial        Yes  Commercial           ELO      Paved     RL
# 7108      Partial        Yes      Others           ELO      Paved      I
#
#       QS_ROOMS  QS_BATHROOM  QS_BEDROOM  \
# 0          4.0          3.9         4.9
# 1          4.9          4.2         2.5
# 2          4.1          3.8         2.2
# 3          4.7          3.9         3.6
# 4          3.0          2.5         4.1
# 5          4.5          2.6         3.1
# 6          3.6          2.1         2.5
# 7          2.4          4.5         2.1
# 8          2.9          3.7         4.0
# 9          3.1          3.1         3.3
# 10         4.0          3.2         4.5
# 11         2.2          3.1         3.3
# 12         2.1          2.5         2.1
# 13         2.2          3.4         3.7
# 14         4.8          2.2         4.9
# 15         3.8          3.8         3.1
# 16         2.3          3.2         4.8
# 17         3.5          4.6         4.7
# 18         4.6          2.6         2.9
# 19         4.5          4.9         4.9
# 20         2.8          2.7         4.9
# 21         4.2          3.1         3.1
# 22         3.4          4.5         3.4
# 23         3.0          3.4         4.9
# 24         4.1          4.4         2.8
# 25         2.8          4.4         4.0
# 26         2.3          2.5         2.2
# 27         2.8          2.7         3.8
# 28         2.7          4.6         4.9
# 29         4.1          5.0         3.0
# ...        ...          ...         ...
# 7079       2.6          4.8         2.0
# 7080       4.8          4.4         4.0
# 7081       2.7          3.8         2.9
# 7082       4.9          3.8         4.2
# 7083       2.4          2.8         2.4
# 7084       2.9          3.0         3.9
# 7085       3.0          4.2         4.8
# 7086       4.7          3.1         4.8
# 7087       2.5          4.5         3.4
# 7088       4.9          4.9         5.0
# 7089       2.4          4.0         4.3
# 7090       5.0          3.7         3.3
# 7091       3.0          2.1         4.4
# 7092       3.1          3.4         3.5
# 7093       3.4          4.6         3.7
# 7094       5.0          5.0         3.0
# 7095       3.7          3.4         2.8
# 7096       3.9          3.8         4.1
# 7097       4.6          3.4         3.2
# 7098       3.2          3.7         2.9
# 7099       3.6          4.7         4.2
# 7100       3.4          3.7         2.1
# 7101       3.2          4.4         2.5
# 7102       4.2          3.0         2.0
# 7103       2.7          3.3         3.6
# 7104       3.0          2.2         2.4
# 7105       3.6          4.5         3.3
# 7106       4.3          4.2         2.9
# 7107       4.6          3.8         4.1
# 7108       3.1          3.5         4.3
#
#                                              QS_OVERALL  COMMIS  SALES_PRICE
# 0                                                  4.33  144400      7600000
# 1                                                 3.765  304049     21717770
# 2                                                  3.09   92114     13159200
# 3                                                  4.01   77042      9630290
# 4                                                  3.29   74063      7406250
# 5                                                  3.32  198316     12394750
# 6                                                  2.67   33955      8488790
# 7                                                  3.26  235204     16800250
# 8                                                  3.55   33236      8308970
# 9                                                  3.16  121255      8083650
# 10                                                 3.83  119504     14938000
# 11                                                 2.89  141746      9449730
# 12                                                 2.26   35097      8774370
# 13                                                 3.19   37546      9386490
# 14                                                 3.66  294494     15499680
# 15    [4.266666666666667, 3.866666666666667, 3.36666...  188569     15714080
# 16                                                 3.57   77904      8656000
# 17                                                  4.3  130951     10912550
# 18                                                 3.35   49725      8287550
# 19                                                 4.76  212032     21203240
# 20                                                 3.39   43622     10905530
# 21                                                 3.43   27558      9185970
# 22                                                 3.73  262210     10925400
# 23                                                 3.73   86646      9627380
# 24                                                 3.59  167073     13922760
# 25                                                 3.74  176415     12601080
# 26                                                 2.29   53533     13383350
# 27                                                 3.17   71457      7939625
# 28                                                 4.18   53090      8848285
# 29                                                 3.83  113382     11338200
# ...                                                 ...     ...          ...
# 7079                                               2.74  104227      8017445
# 7080                                               4.32   68502      7611350
# 7081                                              3.065  171371     14280890
# 7082                                               4.33  146742      9782785
# 7083                                               2.58  111291     11129100
# 7084                                               3.24   30174      7543400
# 7085                                               4.02  203252     11956000
# 7086                                               4.26   59641      4587750
# 7087                                               3.46  200646      9120250
# 7088                                               4.94   57312      7164000
# 7089                                               3.69  210380     14025340
# 7090                                               3.93  122051     11095520
# 7091                                               3.29  160131     11437920
# 7092                                               3.34   25831      8610340
# 7093                                               4.03  141304      9420260
# 7094                                                4.2  353880     14155200
# 7095                                              3.265  146396     13308750
# 7096                                               3.92   86339      9593250
# 7097                                               3.74   70557     14111320
# 7098                                              3.205  209172     13944780
# 7099                                               4.12    7372      7371800
# 7100                                               2.89  312026     19501600
# 7101                                               3.28   74541      6211750
# 7102                                               2.96  141088      5643500
# 7103                                               3.24  178358      9387250
# 7104                                               2.52  107060      5353000
# 7105                                               3.92  205551     10818480
# 7106                                               3.84  167028      8351410
# 7107                                               4.16  119098      8507000
# 7108                                               3.64   79812      9976480
#
# [7104 rows x 19 columns]

# %%
df.dropna(axis = 0, how ='any').shape
# Out:
# (7056, 19)

# %%
df['N_BEDROOM'].mode()
# Out:
# 0    1.0
# dtype: float64

# %%
df['N_BEDROOM'].fillna(value = (df['N_BEDROOM'].mode()[0]), inplace = True)

# %%
df.loc[df['N_BATHROOM'].isnull() == True]
# Out:
#       PRT_ID        AREA  INT_SQFT  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  \
# 70    P05304  Anna Nagar      1589             39        1.0         NaN
# 5087  P01333    Chrompet      1016            105        1.0         NaN
# 6134  P01332    Chormpet       916            173        1.0         NaN
# 6371  P01189    Chrompet      1035             90        1.0         NaN
# 6535  P09189  Anna Nagar      1864            184        2.0         NaN
#
#       N_ROOM    SALE_COND PARK_FACIL BUILDTYPE UTILITY_AVAIL     STREET  \
# 70         4      Partial         No    Others        AllPub     Gravel
# 5087       3     AbNormal        Yes    Others       NoSewr      Gravel
# 6134       3  Normal Sale        Yes    Others           ELO      Paved
# 6371       3      Partial         No    Others        NoSeWa  No Access
# 6535       5       Family        Yes    Others       NoSewr       Paved
#
#      MZZONE  QS_ROOMS  QS_BATHROOM  QS_BEDROOM  QS_OVERALL  COMMIS  \
# 70       RL       2.1          2.5         4.5        3.16   85486
# 5087     RM       3.2          4.2         2.0        3.24  106479
# 6134     RL       3.4          3.5         3.0         NaN   44237
# 6371     RM       2.3          3.5         3.2        3.05   24823
# 6535     RM       3.3          3.7         4.7        3.96  124455
#
#       SALES_PRICE
# 70       12212350
# 5087     10647920
# 6134      8847420
# 6371      8274200
# 6535     15556920

# %%
for i in range(0, len(df)):
    if pd.isnull(df['N_BATHROOM'][i] == True):
        if(df['N_BEDROOM'][i] == 1.0):
            df['N_BATHROOM'][i] == 1.0
        else:
            df['N_BATHROOM'][i] == 2.0

# %%
df.columns
# Out:
# Index(['PRT_ID', 'AREA', 'INT_SQFT', 'DIST_MAINROAD', 'N_BEDROOM',
#        'N_BATHROOM', 'N_ROOM', 'SALE_COND', 'PARK_FACIL', 'BUILDTYPE',
#        'UTILITY_AVAIL', 'STREET', 'MZZONE', 'QS_ROOMS', 'QS_BATHROOM',
#        'QS_BEDROOM', 'QS_OVERALL', 'COMMIS', 'SALES_PRICE'],
#       dtype='object')

# %%
df[['QS_ROOMS', 'QS_BATHROOM','QS_BEDROOM', 'QS_OVERALL']].head()
# Out:
#    QS_ROOMS  QS_BATHROOM  QS_BEDROOM  QS_OVERALL
# 0       4.0          3.9         4.9       4.330
# 1       4.9          4.2         2.5       3.765
# 2       4.1          3.8         2.2       3.090
# 3       4.7          3.9         3.6       4.010
# 4       3.0          2.5         4.1       3.290

# %%
temp = (df['QS_ROOMS'] + df['QS_BATHROOM']  + df['QS_BEDROOM'])/3

# %%
pd.concat([df['QS_ROOMS'],df['QS_BATHROOM'],df['QS_BEDROOM'],temp],axis = 1).head(10)
# Out:
#    QS_ROOMS  QS_BATHROOM  QS_BEDROOM         0
# 0       4.0          3.9         4.9  4.266667
# 1       4.9          4.2         2.5  3.866667
# 2       4.1          3.8         2.2  3.366667
# 3       4.7          3.9         3.6  4.066667
# 4       3.0          2.5         4.1  3.200000
# 5       4.5          2.6         3.1  3.400000
# 6       3.6          2.1         2.5  2.733333
# 7       2.4          4.5         2.1  3.000000
# 8       2.9          3.7         4.0  3.533333
# 9       3.1          3.1         3.3  3.166667

# %%
df.loc[df['QS_OVERALL'].isnull() == True].shape
# Out:
# (48, 19)

# %%
def fill_na(x):
    return((df['QS_ROOMS'] + df['QS_BATHROOM']  + df['QS_BEDROOM'])/3)

# %%
df['QS_OVERALL'] = df.apply(lambda x: fill_na(x) if pd.isnull(x['QS_OVERALL']) else x['QS_OVERALL'],axis = 1)

# %%
df.isnull().sum()
# Out:
# PRT_ID           0
# AREA             0
# INT_SQFT         0
# DIST_MAINROAD    0
# N_BEDROOM        0
# N_BATHROOM       5
# N_ROOM           0
# SALE_COND        0
# PARK_FACIL       0
# BUILDTYPE        0
# UTILITY_AVAIL    0
# STREET           0
# MZZONE           0
# QS_ROOMS         0
# QS_BATHROOM      0
# QS_BEDROOM       0
# QS_OVERALL       0
# COMMIS           0
# SALES_PRICE      0
# dtype: int64

# %%
df.dtypes
# Out:
# PRT_ID            object
# AREA              object
# INT_SQFT           int64
# DIST_MAINROAD      int64
# N_BEDROOM        float64
# N_BATHROOM       float64
# N_ROOM             int64
# SALE_COND         object
# PARK_FACIL        object
# BUILDTYPE         object
# UTILITY_AVAIL     object
# STREET            object
# MZZONE            object
# QS_ROOMS         float64
# QS_BATHROOM      float64
# QS_BEDROOM       float64
# QS_OVERALL        object
# COMMIS             int64
# SALES_PRICE        int64
# dtype: object

# %%
df = df.astype({'N_BEDROOM':'object','N_BATHROOM':'object','N_ROOM':'object'})

# %%
temp = ['AREA','N_BEDROOM','N_BATHROOM','N_ROOM','SALE_COND','PARK_FACIL','BUILDTYPE','UTILITY_AVAIL','STREET','MZZONE']

# %%
for i in temp:
    print('****************Value count in',i,'*************')
    print(df[i].value_counts())
    print('')
# Out:
# ****************Value count in AREA *************
# Chrompet      1681
# Karapakkam    1363
# KK Nagar       996
# Velachery      979
# Anna Nagar     783
# Adyar          773
# T Nagar        496
# Chrompt          9
# Chormpet         6
# Chrmpet          6
# TNagar           5
# Ana Nagar        3
# Karapakam        3
# Velchery         2
# Ann Nagar        2
# KKNagar          1
# Adyr             1
# Name: AREA, dtype: int64
#
# ****************Value count in N_BEDROOM *************
# 1.0    3796
# 2.0    2352
# 3.0     707
# 4.0     254
# Name: N_BEDROOM, dtype: int64
#
# ****************Value count in N_BATHROOM *************
# 1.0    5589
# 2.0    1515
# Name: N_BATHROOM, dtype: int64
#
# ****************Value count in N_ROOM *************
# 4    2563
# 3    2125
# 5    1246
# 2     921
# 6     254
# Name: N_ROOM, dtype: int64
#
# ****************Value count in SALE_COND *************
# AdjLand        1433
# Partial        1429
# Normal Sale    1423
# AbNormal       1406
# Family         1403
# Adj Land          6
# Ab Normal         5
# Partiall          3
# PartiaLl          1
# Name: SALE_COND, dtype: int64
#
# ****************Value count in PARK_FACIL *************
# Yes    3587
# No     3520
# Noo       2
# Name: PARK_FACIL, dtype: int64
#
# ****************Value count in BUILDTYPE *************
# House         2444
# Commercial    2325
# Others        2310
# Other           26
# Comercial        4
# Name: BUILDTYPE, dtype: int64
#
# ****************Value count in UTILITY_AVAIL *************
# AllPub     1886
# NoSeWa     1871
# NoSewr     1829
# ELO        1522
# All Pub       1
# Name: UTILITY_AVAIL, dtype: int64
#
# ****************Value count in STREET *************
# Paved        2560
# Gravel       2520
# No Access    2010
# Pavd           12
# NoAccess        7
# Name: STREET, dtype: int64
#
# ****************Value count in MZZONE *************
# RL    1858
# RH    1822
# RM    1817
# C      550
# A      537
# I      525
# Name: MZZONE, dtype: int64

# %%
df['PARK_FACIL'].replace({'Noo':'No'},inplace = True)

# %%
df['PARK_FACIL'].value_counts()
# Out:
# Yes    3587
# No     3522
# Name: PARK_FACIL, dtype: int64

# %%
df['AREA'].replace({'TNagar':'T Nagar','Adyr':'Adyar','KKNagar':'KK Nagar','Chrompt':'Chrompet','Chormpet':'Chrompet','Chrmpet':'Chrompet'},inplace = True)

# %%
df['AREA'].value_counts()
# Out:
# Chrompet      1702
# Karapakkam    1363
# KK Nagar       997
# Velachery      979
# Anna Nagar     783
# Adyar          774
# T Nagar        501
# Karapakam        3
# Ana Nagar        3
# Velchery         2
# Ann Nagar        2
# Name: AREA, dtype: int64

# %%
df.columns
# Out:
# Index(['PRT_ID', 'AREA', 'INT_SQFT', 'DIST_MAINROAD', 'N_BEDROOM',
#        'N_BATHROOM', 'N_ROOM', 'SALE_COND', 'PARK_FACIL', 'BUILDTYPE',
#        'UTILITY_AVAIL', 'STREET', 'MZZONE', 'QS_ROOMS', 'QS_BATHROOM',
#        'QS_BEDROOM', 'QS_OVERALL', 'COMMIS', 'SALES_PRICE'],
#       dtype='object')

# %%
df.plot.scatter('INT_SQFT','SALES_PRICE')

# %%
df.head(100)
# Out:
#     PRT_ID        AREA  INT_SQFT  DIST_MAINROAD N_BEDROOM N_BATHROOM N_ROOM  \
# 0   P03210  Karapakkam      1004            131         1          1      3
# 1   P09411  Anna Nagar      1986             26         2          1      5
# 2   P01812       Adyar       909             70         1          1      3
# 3   P05346   Velachery      1855             14         3          2      5
# 4   P06210  Karapakkam      1226             84         1          1      3
# 5   P00219    Chrompet      1220             36         2          1      4
# 6   P09105    Chrompet      1167            137         1          1      3
# 7   P09679   Velachery      1847            176         3          2      5
# 8   P03377    Chrompet       771            175         1          1      2
# 9   P09623   Velachery      1635             74         2          1      4
# 10  P09540    Chrompet      1203             78         2          1      4
# 11  P07121    Chrompet      1054            143         1          1      3
# 12  P05512    Chrompet      1196            137         1          1      3
# 13  P09370       Adyar      1056             83         1          1      3
# 14  P04085   Velachery      1865            157         3          2      5
# 15  P06328   Velachery      1868            148         3          2      5
# 16  P06039  Karapakkam      1639            175         2          2      4
# 17  P02016    Chrompet       796            134         1          1      2
# 18  P08160       Adyar      1136             69         1          1      3
# 19  P01372  Anna Nagar      1902            168         2          1      5
# 20  P00936    Chrompet      1069             53         1          1      3
# 21  P07346    Chrompet       931             96         1          1      3
# 22  P06851    KK Nagar      2010            114         3          2      5
# 23  P04665    Chrompet      1074            100         1          1      3
# 24  P00902     T Nagar      1972            111         2          1      5
# 25  P00293     T Nagar      1685            105         1          1      4
# 26  P02235       Adyar      1130             29         1          1      3
# 27  P04080  Karapakkam      1301             59         1          1      3
# 28  P02677       Adyar       730            185         1          1      2
# 29  P00755     T Nagar      1806            138         2          1      5
# ..     ...         ...       ...            ...       ...        ...    ...
# 70  P05304  Anna Nagar      1589             39         1        NaN      4
# 71  P05309       Adyar       668            177         1          1      2
# 72  P09664   Velachery      1724            116         2          1      4
# 73  P02813       Adyar       890            116         1          1      3
# 74  P08933       Adyar      1218             51         2          2      4
# 75  P03590  Anna Nagar      1792             41         1          1      4
# 76  P01725  Karapakkam      1378            192         2          2      4
# 77  P06570  Karapakkam       898             72         1          1      3
# 78  P02686  Anna Nagar      1928            148         2          1      5
# 79  P07789    Chrompet      1233             24         2          1      4
# 80  P08836   Velachery      1618            100         2          1      4
# 81  P02716  Karapakkam       627             49         1          1      2
# 82  P09780   Velachery      1563             43         2          1      4
# 83  P06528  Karapakkam      1693            187         2          2      4
# 84  P06989     T Nagar      1522             85         1          1      4
# 85  P07824       Adyar      1090            171         1          1      3
# 86  P00545    Chrompet      1085            149         1          1      3
# 87  P06461     T Nagar      1687             73         1          1      4
# 88  P07650       Adyar       692             62         1          1      2
# 89  P07887     T Nagar      1518            145         1          1      4
# 90  P08050       Adyar      1025            125         1          1      3
# 91  P04677    KK Nagar      2170            121         3          2      5
# 92  P03124    Chrompet       969             70         1          1      3
# 93  P08147    KK Nagar      1546            129         2          1      4
# 94  P06097    KK Nagar      1709              6         2          1      4
# 95  P00959     T Nagar      1659            103         1          1      4
# 96  P00057    Chrompet       755              8         1          1      2
# 97  P08607       Adyar      1182             50         1          1      3
# 98  P01632       Adyar       735             67         1          1      2
# 99  P00937    Chrompet      1089              0         1          1      3
#
#       SALE_COND PARK_FACIL   BUILDTYPE UTILITY_AVAIL     STREET MZZONE  \
# 0      AbNormal        Yes  Commercial        AllPub      Paved      A
# 1      AbNormal         No  Commercial        AllPub     Gravel     RH
# 2      AbNormal        Yes  Commercial           ELO     Gravel     RL
# 3        Family         No      Others       NoSewr       Paved      I
# 4      AbNormal        Yes      Others        AllPub     Gravel      C
# 5       Partial         No  Commercial        NoSeWa  No Access     RH
# 6       Partial         No       Other        AllPub  No Access     RL
# 7        Family         No  Commercial        AllPub     Gravel     RM
# 8       AdjLand         No      Others       NoSewr       Paved     RM
# 9      AbNormal         No      Others           ELO  No Access      I
# 10      AdjLand        Yes  Commercial        AllPub  No Access     RM
# 11      Partial         No      Others       NoSewr      Gravel     RM
# 12       Family         No      Others       NoSewr   No Access     RL
# 13      Partial        Yes      Others       NoSewr       Paved     RH
# 14       Family         No  Commercial       NoSewr       Paved     RM
# 15       Family         No  Commercial       NoSewr      Gravel     RH
# 16  Normal Sale        Yes       House           ELO     Gravel      I
# 17      AdjLand        Yes  Commercial        AllPub  No Access     RL
# 18  Normal Sale        Yes      Others        AllPub      Paved      A
# 19       Family        Yes  Commercial           ELO      Paved     RL
# 20     AbNormal        Yes      Others       NoSewr       Paved     RM
# 21     AbNormal        Yes      Others           ELO      Paved     RL
# 22      Partial         No      Others       NoSewr      Gravel     RH
# 23     AbNormal         No      Others       NoSewr      Gravel     RL
# 24      AdjLand         No      Others       NoSewr   No Access     RH
# 25       Family         No       House       NoSewr      Gravel     RM
# 26       Family        Yes  Commercial           ELO      Paved     RH
# 27  Normal Sale        Yes      Others       NoSewr      Gravel      C
# 28      AdjLand        Yes       House           ELO     Gravel     RL
# 29       Family         No       House        NoSeWa      Paved     RH
# ..          ...        ...         ...           ...        ...    ...
# 70      Partial         No      Others        AllPub     Gravel     RL
# 71     AbNormal        Yes  Commercial        NoSeWa     Gravel      I
# 72     AbNormal        Yes       House           ELO  No Access     RL
# 73     AbNormal        Yes       House       NoSewr       Paved      C
# 74  Normal Sale         No  Commercial        AllPub  No Access      I
# 75       Family        Yes       House           ELO     Gravel     RM
# 76      AdjLand         No      Others       NoSewr      Gravel     RM
# 77      Partial        Yes  Commercial       NoSewr       Paved     RH
# 78      Partial         No       House        AllPub  No Access     RH
# 79     AbNormal         No       House        NoSeWa     Gravel     RM
# 80      AdjLand        Yes      Others       NoSewr       Paved      C
# 81       Family         No       House       NoSewr      Gravel     RM
# 82       Family         No       House        NoSeWa     Gravel     RM
# 83  Normal Sale        Yes  Commercial       NoSewr      Gravel      C
# 84      Partial         No  Commercial        AllPub     Gravel     RL
# 85      Partial        Yes      Others        NoSeWa     Gravel     RH
# 86     AbNormal        Yes  Commercial       NoSewr      Gravel     RL
# 87     AbNormal         No      Others       NoSewr       Paved     RH
# 88  Normal Sale        Yes  Commercial        AllPub      Paved     RH
# 89       Family        Yes  Commercial        AllPub      Paved     RH
# 90      Partial         No  Commercial        NoSeWa      Paved      I
# 91       Family        Yes       House       NoSewr      Gravel     RL
# 92       Family        Yes  Commercial           ELO  No Access     RH
# 93     AbNormal         No  Commercial        AllPub     Gravel     RM
# 94     AbNormal        Yes       House        NoSeWa      Paved     RL
# 95      AdjLand        Yes      Others        NoSeWa  No Access     RL
# 96  Normal Sale         No  Commercial           ELO     Gravel     RM
# 97  Normal Sale        Yes       House        AllPub  No Access     RL
# 98      AdjLand         No  Commercial        NoSeWa  No Access     RH
# 99  Normal Sale        Yes       House           ELO      Paved     RL
#
#     QS_ROOMS  QS_BATHROOM  QS_BEDROOM  \
# 0        4.0          3.9         4.9
# 1        4.9          4.2         2.5
# 2        4.1          3.8         2.2
# 3        4.7          3.9         3.6
# 4        3.0          2.5         4.1
# 5        4.5          2.6         3.1
# 6        3.6          2.1         2.5
# 7        2.4          4.5         2.1
# 8        2.9          3.7         4.0
# 9        3.1          3.1         3.3
# 10       4.0          3.2         4.5
# 11       2.2          3.1         3.3
# 12       2.1          2.5         2.1
# 13       2.2          3.4         3.7
# 14       4.8          2.2         4.9
# 15       3.8          3.8         3.1
# 16       2.3          3.2         4.8
# 17       3.5          4.6         4.7
# 18       4.6          2.6         2.9
# 19       4.5          4.9         4.9
# 20       2.8          2.7         4.9
# 21       4.2          3.1         3.1
# 22       3.4          4.5         3.4
# 23       3.0          3.4         4.9
# 24       4.1          4.4         2.8
# 25       2.8          4.4         4.0
# 26       2.3          2.5         2.2
# 27       2.8          2.7         3.8
# 28       2.7          4.6         4.9
# 29       4.1          5.0         3.0
# ..       ...          ...         ...
# 70       2.1          2.5         4.5
# 71       4.9          2.9         3.5
# 72       3.8          2.2         2.0
# 73       2.5          4.7         5.0
# 74       4.7          3.9         3.3
# 75       2.7          2.6         2.0
# 76       4.2          2.8         2.6
# 77       2.4          3.1         2.1
# 78       3.4          4.1         2.4
# 79       2.2          2.0         4.6
# 80       4.0          4.3         4.1
# 81       4.3          2.8         2.5
# 82       4.7          4.5         2.6
# 83       3.9          2.1         3.9
# 84       4.2          3.6         3.5
# 85       3.1          2.7         2.3
# 86       2.8          3.8         4.6
# 87       4.6          4.6         2.0
# 88       4.1          4.4         5.0
# 89       3.7          3.5         4.1
# 90       2.5          2.5         2.7
# 91       3.7          4.6         4.0
# 92       3.4          2.4         4.0
# 93       2.5          4.3         2.8
# 94       4.3          3.7         2.0
# 95       3.8          2.3         3.8
# 96       3.8          4.4         2.7
# 97       3.2          3.5         3.1
# 98       2.7          4.0         4.0
# 99       2.7          2.9         3.1
#
#                                            QS_OVERALL  COMMIS  SALES_PRICE
# 0                                                4.33  144400      7600000
# 1                                               3.765  304049     21717770
# 2                                                3.09   92114     13159200
# 3                                                4.01   77042      9630290
# 4                                                3.29   74063      7406250
# 5                                                3.32  198316     12394750
# 6                                                2.67   33955      8488790
# 7                                                3.26  235204     16800250
# 8                                                3.55   33236      8308970
# 9                                                3.16  121255      8083650
# 10                                               3.83  119504     14938000
# 11                                               2.89  141746      9449730
# 12                                               2.26   35097      8774370
# 13                                               3.19   37546      9386490
# 14                                               3.66  294494     15499680
# 15  [4.266666666666667, 3.866666666666667, 3.36666...  188569     15714080
# 16                                               3.57   77904      8656000
# 17                                                4.3  130951     10912550
# 18                                               3.35   49725      8287550
# 19                                               4.76  212032     21203240
# 20                                               3.39   43622     10905530
# 21                                               3.43   27558      9185970
# 22                                               3.73  262210     10925400
# 23                                               3.73   86646      9627380
# 24                                               3.59  167073     13922760
# 25                                               3.74  176415     12601080
# 26                                               2.29   53533     13383350
# 27                                               3.17   71457      7939625
# 28                                               4.18   53090      8848285
# 29                                               3.83  113382     11338200
# ..                                                ...     ...          ...
# 70                                               3.16   85486     12212350
# 71                                                3.8  102836     10283575
# 72                                               2.54  152260      8956480
# 73                                               4.19   43124      7187350
# 74                                               3.84  138323     12574850
# 75                                              2.395  250313     13906270
# 76                                               3.14  208268      9917500
# 77                                               2.49  215744      8629750
# 78                                              3.175  105003     11667050
# 79                                               2.84  107989      9817150
# 80                                               4.17   92631      9263050
# 81                                               3.13   92225      6587500
# 82                                               3.98  195987      9799360
# 83                                               3.36  166420     12801500
# 84                                              3.735  174545     17454510
# 85                                               2.62   98324      9832420
# 86  [4.266666666666667, 3.866666666666667, 3.36666...  100545     14363500
# 87                                               3.43  224582     12476770
# 88                                               4.61  124576     10381355
# 89                                               3.83  158402     17600240
# 90                                                2.6  142153     10934875
# 91                                               4.09  284560     12372160
# 92                                               3.18  146234     11248750
# 93                                               3.16  142411     14241140
# 94                                                3.2  233694     10160600
# 95                                              3.425  216625     13539080
# 96                                               3.71   42911     10727750
# 97                                               3.21   39468      9867055
# 98                                               3.61  132702      9478710
# 99                                                2.9   45251      9050200
#
# [100 rows x 19 columns]

# %%
df.plot.scatter('QS_BEDROOM','SALES_PRICE')

# %%
df.pivot_table( values='SALES_PRICE',index='N_BEDROOM',columns='N_BATHROOM',aggfunc='median')
# Out:
# N_BATHROOM         1.0         2.0
# N_BEDROOM
# 1.0          9168740.0         NaN
# 2.0         12129780.0   9117500.0
# 3.0                NaN  11652865.0
# 4.0                NaN  13172000.0
